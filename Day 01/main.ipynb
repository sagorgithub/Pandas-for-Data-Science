# %% [markdown]
# # Pandas For Python

# %% [markdown]
# pandas install

# %%
# !python -m pip install --user pandas
# Out:
# Collecting pandas
#   Using cached pandas-2.3.1-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Using cached numpy-2.3.2-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\win 10\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\win 10\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-2.3.1-cp313-cp313-win_amd64.whl (11.0 MB)
# Using cached numpy-2.3.2-cp313-cp313-win_amd64.whl (12.8 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
#
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------- ----------------------------- 1/4 [tzdata]
#    ---------- ----------------------------- 1/4 [tzdata]
#    ---------- ----------------------------- 1/4 [tzdata]
#    ---------- ----------------------------- 1/4 [tzdata]
#    ---------- ----------------------------- 1/4 [tzdata]
#    ---------- ----------------------------- 1/4 [tzdata]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ------------------------------ --------- 3/4 [pandas]
#    ---------------------------------------- 4/4 [pandas]
#
# Successfully installed numpy-2.3.2 pandas-2.3.1 pytz-2025.2 tzdata-2025.2
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'C:\Users\Win 10\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %% [markdown]
# # Pandas Import

# %%
import pandas as pd

# %%
#create a simple list
data = [1, 2, 3, 4, 5]

# %%
print(data)
# Out:
# [1, 2, 3, 4, 5]

# %%
type(data)
# Out:
# list

# %%
#create a pandas Series from the list
series_data = pd.Series(data)
series_data
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
type(series_data)
# Out:
# pandas.core.series.Series

# %%
#create a DataFrame from the Series
df = pd.DataFrame(series_data, columns=['Data Frame'])
df
# Out:
#    Data Frame
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5

# %%
data
# Out:
# [1, 2, 3, 4, 5]

# %%
#create a DataFrame from the list
df = pd.DataFrame(data, columns=['Data Frame'])
df
# Out:
#    Data Frame
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5
